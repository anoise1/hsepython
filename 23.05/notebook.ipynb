# %%
import numpy as np
import random

# %%
a = np.arange(1, 11)
random.shuffle(a)
a
# Out:
# array([ 6, 10,  1,  2,  3,  9,  5,  7,  8,  4])

# %%
np.where(a % 2 == 0, a, 0)
# Out:
# array([ 6, 10,  0,  2,  0,  0,  0,  0,  8,  4])

# %%
a.reshape(2, 5).ravel()
a = a * 3
a + a
# Out:
# array([36, 60,  6, 12, 18, 54, 30, 42, 48, 24])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.Series(a)
# Out:
# 0    18
# 1    30
# 2     3
# 3     6
# 4     9
# 5    27
# 6    15
# 7    21
# 8    24
# 9    12
# dtype: int64

# %%
pd.DataFrame(a.reshape(5, 2))
# Out:
#     0   1
# 0  18  30
# 1   3   6
# 2   9  27
# 3  15  21
# 4  24  12

# %% [markdown]
# титаник

# %%
df = pd.read_csv('train.csv', index_col='PassengerId')
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
df['Fare'].mean(), df['Fare'].median(), df['Fare'].quantile(0.75)
# Out:
# (np.float64(32.204207968574636), np.float64(14.4542), np.float64(31.0))

# %%
df['Fare'].quantile(0.95)
# Out:
# np.float64(112.07915)

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe(include='int64')
# Out:
#          Survived      Pclass       SibSp       Parch
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.523008    0.381594
# std      0.486592    0.836071    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000    0.000000
# 50%      0.000000    3.000000    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000    0.000000
# max      1.000000    3.000000    8.000000    6.000000

# %%
df[df.Fare > 10]
df[[True, False, True] * 297]
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6                   0       3                              Moran, Mr. James
# 7                   0       1                       McCarthy, Mr. Timothy J
# ...               ...     ...                                           ...
# 885                 0       3                        Sutehall, Mr. Henry Jr
# 886                 0       3          Rice, Mrs. William (Margaret Norton)
# 888                 1       1                  Graham, Miss. Margaret Edith
# 889                 0       3      Johnston, Miss. Catherine Helen "Carrie"
# 891                 0       3                           Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500   NaN
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 4            female  35.0      1      0            113803  53.1000  C123
# 6              male   NaN      0      0            330877   8.4583   NaN
# 7              male  54.0      0      0             17463  51.8625   E46
# ...             ...   ...    ...    ...               ...      ...   ...
# 885            male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN
# 886          female  39.0      0      5            382652  29.1250   NaN
# 888          female  19.0      0      0            112053  30.0000   B42
# 889          female   NaN      1      2        W./C. 6607  23.4500   NaN
# 891            male  32.0      0      0            370376   7.7500   NaN
#
#             Embarked
# PassengerId
# 1                  S
# 3                  S
# 4                  S
# 6                  Q
# 7                  S
# ...              ...
# 885                S
# 886                Q
# 888                S
# 889                S
# 891                Q
#
# [594 rows x 11 columns]

# %%
df.iloc[:10, 3:6]
# Out:
#                 Sex   Age  SibSp
# PassengerId
# 1              male  22.0      1
# 2            female  38.0      1
# 3            female  26.0      0
# 4            female  35.0      1
# 5              male  35.0      0
# 6              male   NaN      0
# 7              male  54.0      0
# 8              male   2.0      3
# 9            female  27.0      0
# 10           female  14.0      1

# %%
df[df.Fare > 30].loc[:10, 'Survived':'Sex']
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 10                  1       2
#
#                                                           Name     Sex
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 7                                      McCarthy, Mr. Timothy J    male
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female

# %% [markdown]
# титул из имени

# %%
def processing(s):
    return s[:s.find('.')].split()[-1]

df['Title'] = df.Name.apply(processing)

# %%
df.groupby('Title').agg({'Fare': ['mean', 'median']}).loc['Mr', ('Fare', 'mean')]
# Out:
# np.float64(24.44155996131528)

# %%
df.groupby('Title').agg({'Fare': ['mean', 'median']})
df.Title.value_counts() > 10
b = ['Mr', 'Miss', 'Mrs', 'Master']
title_df = df[df.Title.isin(b)]
title_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 886                 0       3
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 886                       Rice, Mrs. William (Margaret Norton)  female  39.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked Title
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S    Mr
# 2                1      0          PC 17599  71.2833   C85        C   Mrs
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S  Miss
# 4                1      0            113803  53.1000  C123        S   Mrs
# 5                0      0            373450   8.0500   NaN        S    Mr
# ...            ...    ...               ...      ...   ...      ...   ...
# 886              0      5            382652  29.1250   NaN        Q   Mrs
# 888              0      0            112053  30.0000   B42        S  Miss
# 889              1      2        W./C. 6607  23.4500   NaN        S  Miss
# 890              0      0            111369  30.0000  C148        C    Mr
# 891              0      0            370376   7.7500   NaN        Q    Mr
#
# [864 rows x 12 columns]

# %%
title_df.groupby(['Title', 'Pclass']).agg({'Fare': 'median'})
# Out:
#                     Fare
# Title  Pclass
# Master 1       120.00000
#        2        26.00000
#        3        28.51250
# Miss   1        91.75000
#        2        13.00000
#        3         8.75625
# Mr     1        42.40000
#        2        13.00000
#        3         7.89580
# Mrs    1        79.42500
#        2        26.00000
#        3        15.97500

# %%
pd.pivot_table(title_df, columns='Title', index='Pclass', values='Fare', aggfunc='median').style.background_gradient(cmap='twilight_shifted_r')
# Out:
# <style type="text/css">
# #T_628c4_row0_col0, #T_628c4_row0_col1, #T_628c4_row0_col2, #T_628c4_row0_col3 {
#   background-color: #301437;
#   color: #f1f1f1;
# }
# #T_628c4_row1_col0, #T_628c4_row2_col1, #T_628c4_row2_col2, #T_628c4_row2_col3 {
#   background-color: #2f1436;
#   color: #f1f1f1;
# }
# #T_628c4_row1_col1 {
#   background-color: #44123f;
#   color: #f1f1f1;
# }
# #T_628c4_row1_col2 {
#   background-color: #832550;
#   color: #f1f1f1;
# }
# #T_628c4_row1_col3 {
#   background-color: #882850;
#   color: #f1f1f1;
# }
# #T_628c4_row2_col0 {
#   background-color: #381139;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_628c4">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Title</th>
#       <th id="T_628c4_level0_col0" class="col_heading level0 col0" >Master</th>
#       <th id="T_628c4_level0_col1" class="col_heading level0 col1" >Miss</th>
#       <th id="T_628c4_level0_col2" class="col_heading level0 col2" >Mr</th>
#       <th id="T_628c4_level0_col3" class="col_heading level0 col3" >Mrs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_628c4_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_628c4_row0_col0" class="data row0 col0" >120.000000</td>
#       <td id="T_628c4_row0_col1" class="data row0 col1" >91.750000</td>
#       <td id="T_628c4_row0_col2" class="data row0 col2" >42.400000</td>
#       <td id="T_628c4_row0_col3" class="data row0 col3" >79.425000</td>
#     </tr>
#     <tr>
#       <th id="T_628c4_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_628c4_row1_col0" class="data row1 col0" >26.000000</td>
#       <td id="T_628c4_row1_col1" class="data row1 col1" >13.000000</td>
#       <td id="T_628c4_row1_col2" class="data row1 col2" >13.000000</td>
#       <td id="T_628c4_row1_col3" class="data row1 col3" >26.000000</td>
#     </tr>
#     <tr>
#       <th id="T_628c4_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_628c4_row2_col0" class="data row2 col0" >28.512500</td>
#       <td id="T_628c4_row2_col1" class="data row2 col1" >8.756250</td>
#       <td id="T_628c4_row2_col2" class="data row2 col2" >7.895800</td>
#       <td id="T_628c4_row2_col3" class="data row2 col3" >15.975000</td>
#     </tr>
#   </tbody>
# </table>

# %%
def age_group(age):
    if age < 12:
        return 'kid'
    if 18 > age:
        return 'teen'
    if 25 > age:
        return 'young adult'
    return 'old'

df.drop('Cabin', axis=1)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Embarked Title
# PassengerId
# 1                1      0         A/5 21171   7.2500        S    Mr
# 2                1      0          PC 17599  71.2833        C   Mrs
# 3                0      0  STON/O2. 3101282   7.9250        S  Miss
# 4                1      0            113803  53.1000        S   Mrs
# 5                0      0            373450   8.0500        S    Mr
# ...            ...    ...               ...      ...      ...   ...
# 887              0      0            211536  13.0000        S   Rev
# 888              0      0            112053  30.0000        S  Miss
# 889              1      2        W./C. 6607  23.4500        S  Miss
# 890              0      0            111369  30.0000        C    Mr
# 891              0      0            370376   7.7500        Q    Mr
#
# [891 rows x 11 columns]

# %%
df.rename({'Cabin': 'Каюта'}, axis=1)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Каюта Embarked Title
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S    Mr
# 2                1      0          PC 17599  71.2833   C85        C   Mrs
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S  Miss
# 4                1      0            113803  53.1000  C123        S   Mrs
# 5                0      0            373450   8.0500   NaN        S    Mr
# ...            ...    ...               ...      ...   ...      ...   ...
# 887              0      0            211536  13.0000   NaN        S   Rev
# 888              0      0            112053  30.0000   B42        S  Miss
# 889              1      2        W./C. 6607  23.4500   NaN        S  Miss
# 890              0      0            111369  30.0000  C148        C    Mr
# 891              0      0            370376   7.7500   NaN        Q    Mr
#
# [891 rows x 12 columns]

# %%
a = pd.DataFrame(np.arange(16).reshape(4, 4))
b = pd.DataFrame(np.arange(32).reshape(8, 4), columns=['A', 'B', 'C', 'D'])
a.columns = ['A', 'B', 'C', 'D']
pd.concat([a, b], axis=1).reset_index(drop=True)
# Out:
#       A     B     C     D   A   B   C   D
# 0   0.0   1.0   2.0   3.0   0   1   2   3
# 1   4.0   5.0   6.0   7.0   4   5   6   7
# 2   8.0   9.0  10.0  11.0   8   9  10  11
# 3  12.0  13.0  14.0  15.0  12  13  14  15
# 4   NaN   NaN   NaN   NaN  16  17  18  19
# 5   NaN   NaN   NaN   NaN  20  21  22  23
# 6   NaN   NaN   NaN   NaN  24  25  26  27
# 7   NaN   NaN   NaN   NaN  28  29  30  31

# %%
df.Age.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>
